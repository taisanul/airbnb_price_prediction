# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
folderpath = '/content/drive/MyDrive/ML/airbnb_price_prediction'

# %%
# !pip install textblob
# !pip install geopy
# !pip install xgboost
# !pip install lightgbm

# %%
# %cd $folderpath
# !python3 main.py
# Out:
# /content/drive/MyDrive/ML/airbnb_price_prediction
# 2025-07-18 08:29:16,329 - INFO - Created directories
# 2025-07-18 08:29:16,329 - INFO - ==================================================
# 2025-07-18 08:29:16,329 - INFO - STEP 1: Loading and cleaning data
# 2025-07-18 08:29:16,329 - INFO - ==================================================
# 2025-07-18 08:29:16,329 - INFO - Loading datasets...
# 2025-07-18 08:29:18,563 - INFO - Listings shape: (447, 79)
# 2025-07-18 08:29:18,563 - INFO - Reviews shape: (25991, 6)
# 2025-07-18 08:29:18,563 - INFO - Calendar shape: (0, 7)
# 2025-07-18 08:29:18,563 - INFO - Cleaning data...
# 2025-07-18 08:29:18,576 - INFO - Removed 3 price outliers
# 2025-07-18 08:29:18,592 - INFO - Converting boolean column: host_is_superhost
# 2025-07-18 08:29:18,596 - INFO - Converting boolean column: host_has_profile_pic
# 2025-07-18 08:29:18,597 - INFO - Converting boolean column: host_identity_verified
# ...
